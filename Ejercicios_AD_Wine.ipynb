# %% [markdown]
# <a href="https://colab.research.google.com/github/slapazromero/Ejercicio_AD_Wine/blob/main/Ejercicios_AD_Wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importación de librerías necesarias.

# %%
import pydot
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
from IPython.display import Image
from io import StringIO
from joblib import dump

# %% [markdown]
# # Preproceso.

# %% [markdown]
# ## Importacion de los datos del dataset.

# %%
wine = pd.read_csv('WineQT.csv')

# %% [markdown]
# ## Mostrar las primeras y ultimas filas del dataframe importado.

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %% [markdown]
# ## Modificaciones de los datos.

# %%
wine = wine.drop('Id', axis=1)

# %% [markdown]
# ## Mostrar las primeras y ultimas filas del dataframe modificado.

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 1138     11.0        6
# 1139      9.5        6
# 1140     10.5        5
# 1141     11.2        6
# 1142     10.2        5

# %% [markdown]
# ## Mostrar parámetros estadísticos de los datos (media, desviación típica, cuartiles, etc.)

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043
# std       0.156664     0.170399     1.082196     0.805824
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.205000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# ## Mostrar un mapa de calor que indique la correlación entre variables.

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.heatmap(wine.corr(), annot=True)

# %% [markdown]
# ## Seleccionar las características a tener en cuenta en el estudio.

# %%
caracteristicas = ['volatile acidity', 'alcohol']
resultado = ['quality']

# %% [markdown]
# ## Separar datos entre datos de entrada y etiquetas (resultados).

# %%
x_wine = wine[caracteristicas]
y_wine = wine[resultado]

# %% [markdown]
# ## Separar datos entre entrenamiento y prueba (usando un 80% para entrenamiento y 20% para test)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_wine, y_wine, test_size=0.20)

# %% [markdown]
# # Optimización de hiperparámetros.

# %% [markdown]
# ## Validación cruzada.

# %%
def validacion_cruzada(max_depth, x_train, y_train, criterion):
  kf = KFold(n_splits=5)

  model = DecisionTreeClassifier(max_depth = max_depth, criterion = criterion)
  scores = []

  for train_fold, test_fold in kf.split(x_train):
    model.fit(x_train.values[train_fold], y_train.values[train_fold].ravel())
    y_predict = model.predict(x_train.values[test_fold])
    scores.append(accuracy_score(y_train.values[test_fold], y_predict))
  return np.mean(scores)

# %%
resultados = []
for criterion in range(2):
  for max_depth in range(1, 16):
    if criterion == 0:
      resultados.append((validacion_cruzada(max_depth, x_train, y_train, 'gini'), max_depth, 'gini'))
    elif criterion == 1:
      resultados.append((validacion_cruzada(max_depth, x_train, y_train, 'entropy'), max_depth, 'entropy'))

mejor_resultado = max(resultados)
print(mejor_resultado)
# Out:
# (0.5809764006485318, 3, 'entropy')

# %% [markdown]
# # Entrenamiento y predicción.

# %% [markdown]
# ## Elegir, instanciar y entrenar el modelo.

# %%
model = DecisionTreeClassifier(max_depth = mejor_resultado[1], criterion = mejor_resultado[2])

# %% [markdown]
# ## Realizar una predicción con los datos de prueba.

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
y_predict = model.predict(x_test)

# %% [markdown]
# ## Mostrar el árbol de decisión resultante.

# %%
dot_data = StringIO()
export_graphviz(model, out_file = dot_data, class_names = [str(x) for x in model.classes_], feature_names = x_train.columns, rounded = True, filled = True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())

# %% [markdown]
# ## Mostrar la importancia de cada atributo en el árbol resultante.

# %%
print('Features Relevances')
pd.DataFrame({'Attributes': ('volatile acidity', 'alcohol'), 'Decision Tree': model.feature_importances_ })
# Out:
# Features Relevances
#          Attributes  Decision Tree
# 0  volatile acidity       0.292517
# 1           alcohol       0.707483

# %% [markdown]
# ## Intenta guardar el modelo de predicción ya entrenado usando dump

# %%
dump(model, 'modelos_entrenado.AD_Wine')
# Out:
# ['modelos_entrenado.AD_Wine']

# %% [markdown]
# # Evaluación.

# %% [markdown]
# ##  Mostrar el porcentaje de elementos correctamente clasificados.

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.5109170305676856

# %% [markdown]
# ## Mostrar la predicción realizada (imprimir la variable con la predicción).

# %%
y_predict
# Out:
# array([6, 5, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 6, 6, 5, 5, 6, 6, 6, 5,
#        5, 5, 6, 5, 5, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 6, 5, 5, 6, 5, 5,
#        6, 6, 5, 5, 6, 5, 5, 6, 5, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 5, 6, 5,
#        5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 5, 6, 6, 5, 6, 5, 5, 5, 6, 6, 5, 6,
#        5, 5, 5, 6, 5, 5, 5, 6, 6, 6, 5, 5, 6, 6, 6, 5, 6, 5, 6, 6, 5, 6,
#        6, 6, 6, 5, 6, 6, 6, 5, 5, 6, 5, 6, 6, 6, 5, 6, 5, 6, 5, 5, 5, 5,
#        5, 5, 6, 6, 5, 6, 5, 6, 5, 5, 6, 5, 5, 6, 6, 5, 5, 5, 6, 6, 5, 5,
#        6, 6, 6, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5,
#        6, 5, 6, 5, 5, 6, 5, 5, 6, 5, 5, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 6,
#        6, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 5,
#        6, 5, 5, 5, 5, 6, 5, 5, 5])

# %% [markdown]
# ## Representar gráficamente la clasificación obtenida (matriz de confusión).

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_predict)
plt.grid(b=None)
